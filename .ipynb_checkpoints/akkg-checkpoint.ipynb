# %%
import pandas as pd
import nltk
import json
import gensim
import tqdm

# %% [markdown]
# ### Get text and load as a DataFrame

# %%
## Get text and load as a DataFrame

nltk.download('punkt')

def read_book_to_dataframe(file_path):
    # Read the text file
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()

    # Split the text into sentences
    sentences = nltk.tokenize.sent_tokenize(text)

    # Create a DataFrame
    df = pd.DataFrame(sentences, columns=['Sentence'])

    return df

# Using the .txt file that's in the same directory
file_path = 'anna_karenina.txt'
df = read_book_to_dataframe(file_path)

df.head()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/evanwineland/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                                                                                                                                                                   Sentence
# 0                                                                                                       PART ONE\nChapter 1\nHappy families are all alike; every unhappy family is unhappy in its own way.
# 1                                                                                                                                                     Everything was in confusion in the Oblonskys’ house.
# 2  The wife had discovered that the husband was carrying on an intrigue with a French girl, who had been a governess in their family, and she had announced to her husband that she could not go on liv...
# 3                     This position of affairs had now lasted three days, and not only the husband and wife themselves, but all the members of their family and household, were painfully conscious of it.
# 4  Every person in the house felt that there was no sense in their living together, and that the stray people brought together by chance in any inn had more in common with one another than they, the ...

# %%
## Note: install spacy at the command line first.  Then, download en_core_web_sim
import re
import bs4
import requests
import spacy
import networkx as nx
import matplotlib.pyplot as plt

from tqdm import tqdm
from spacy import displacy
from spacy.matcher import Matcher 
from spacy.tokens import Span 

# nlp = spacy.load("en_core_web_sm")

pd.set_option('display.max_colwidth', 200)

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def get_entities(sent):
  ## chunk 1
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  #############################################################
  
  for tok in nlp(sent):
    ## chunk 2
    # only analyze if the current token isn't punctuation
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      ## chunk 3
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      ## chunk 4
      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      ## chunk 5  
      # update variables
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
  #############################################################

  return [ent1.strip(), ent2.strip()]

# %%
df.shape[0], df.head()
# Out:
# (16807,
#                                                                                                                                                                                                    Sentence
#  0                                                                                                       PART ONE\nChapter 1\nHappy families are all alike; every unhappy family is unhappy in its own way.
#  1                                                                                                                                                     Everything was in confusion in the Oblonskys’ house.
#  2  The wife had discovered that the husband was carrying on an intrigue with a French girl, who had been a governess in their family, and she had announced to her husband that she could not go on liv...
#  3                     This position of affairs had now lasted three days, and not only the husband and wife themselves, but all the members of their family and household, were painfully conscious of it.
#  4  Every person in the house felt that there was no sense in their living together, and that the stray people brought together by chance in any inn had more in common with one another than they, the ...)

# %%
get_entities(df['Sentence'][0])
# Out:
# ['unhappy  family', 'own  way']

# %%
e_pairs = []

for i in tqdm(df["Sentence"]):
    e_pairs.append(get_entities(i))
# Out:
# 100%|████████████████████████████████████| 16807/16807 [01:51<00:00, 150.67it/s]

# %%
e_pairs[0:10]
# Out:
# [['unhappy  family', 'own  way'],
#  ['Everything', 'Oblonskys  house'],
#  ['she', 'same  him'],
#  ['only  husband', 'painfully  it'],
#  ['stray  people', 'common  Oblonskys'],
#  ['own  husband', 'three  days'],
#  ['just kitchen coachman', 'warning'],
#  ['days Stepan Arkadyevitch he', 'covered  study'],
#  ['once  he', 'eyes'],
#  ['now  he', 'dream']]

# %%
def get_relation(sent):

    doc = nlp(sent)

    # Matcher class object 
    matcher = Matcher(nlp.vocab)

    #define the pattern 
    pattern = [{'DEP':'ROOT'},
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 

    matcher.add("matching_1", [pattern]) 

    matches = matcher(doc)
    k = len(matches) - 1

    span = doc[matches[k][1]:matches[k][2]] 

    return(span.text)

# %%
get_relation("Kaan finished the race.")
# Out:
# 'finished'

# %%
relations = [get_relation(i) for i in df["Sentence"]]
relations[:50]
# Out:
# ['is unhappy',
#  'was in',
#  'discovered',
#  'lasted',
#  'felt',
#  'been at',
#  'walked off',
#  'woke',
#  'embraced',
#  'thought',
#  'was',
#  'be sure',
#  'giving',
#  'was in',
#  'remembered',
#  'twinkled',
#  'was nice',
#  'dropped',
#  'stretched',
#  'remembered',
#  'Ah',
#  'muttered',
#  'was present',
#  'forgive',
#  'is',
#  'reflected',
#  'kept',
#  'was',
#  'fussing',
#  '’s',
#  'this',
#  'was',
#  'happened to',
#  'succeed in',
#  'reflected',
#  'smile',
#  'shuddered',
#  'refused',
#  'thought',
#  '’s',
#  'said to',
#  'was',
#  'was incapable',
#  'at',
#  'was',
#  'felt',
#  'managed',
#  'thought',
#  'supposed',
#  'turned']

# %% [markdown]
# ### Create and visualize the KG using entities and relationships

# %%
source = [i[0] for i in e_pairs]
target = [i[1] for i in e_pairs]

# %%
kg_df = pd.DataFrame({'source': source, 'target': target, 'relation': relations})
kg_df.head()
# Out:
#             source             target    relation
# 0  unhappy  family           own  way  is unhappy
# 1       Everything   Oblonskys  house      was in
# 2              she          same  him  discovered
# 3    only  husband      painfully  it      lasted
# 4    stray  people  common  Oblonskys        felt

# %%
graph = nx.from_pandas_edgelist(kg_df[kg_df['source']=="Anna"], "source", "target", edge_attr = True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(graph, k = .5)
nx.draw(graph, with_labels=True, node_color = 'orange', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos, font_weight = 'bold')

plt.show()

# %% [markdown]
# Getting edge labels required I compromise on having a directed graph with multiple edges between nodes.
#
# I also want to limit the number of these that I have.

# %%
## Make the graph, but with labeled edges
graph = nx.from_pandas_edgelist(kg_df[kg_df['source']=="Anna"], "source", "target", edge_attr = True, create_using=nx.DiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(graph, k = .5)
nx.draw(graph, with_labels=True, node_color = 'red', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos, font_weight = 'bold')

#Draw labels
edge_labels = nx.get_edge_attributes(graph, 'relation')
nx.draw_networkx_edge_labels(graph, pos, edge_labels=edge_labels)

plt.show()

# %% [markdown]
# ### Some quick entity normalization
#
# Let's do a quick pass to make sure all Anna, Stepan, Vronsky, and Karenin nodes are treated as the same entity.

# %%
pd.Series(source).value_counts()[:50]
# Out:
# he                       1422
#                           982
# she                       859
# I                         811
# He                        382
# it                        375
# you                       290
# She                       275
# Levin                     250
# who                       196
# that                      178
# they                      164
# Stepan Arkadyevitch       133
# It                        130
# Anna                      127
# Vronsky                   124
# Kitty                     107
# You                        95
# Alexey Alexandrovitch      83
# They                       80
# we                         78
# what                       71
# when  he                   69
# which                      67
# Sergey Ivanovitch          59
# one                        56
# We                         48
# this                       44
# him                        43
# when  she                  37
# so  he                     37
# how  he                    32
# Darya Alexandrovna         32
# That                       31
# her                        31
# now  he                    31
# how  it                    29
# eyes                       27
# so  she                    27
# Varenka                    26
# now  she                   25
# Why  you                   25
# face                       24
# how  I                     23
# This                       22
# again  he                  22
# everything                 22
# old  man                   21
# mother                     21
# Betsy                      20
# Name: count, dtype: int64

# %%
# Replace a source if it's "he" or "she" with the previous source if it's in an allowed list of names
def replace_pronouns(df):
    
    pronouns = ["he", "she"]
    allowed_replacement_names = ["Anna", "Anna Arkadyevna", "Stepan Arkadyevitch", "Stiva", "Oblonsky",
                                 "Konstantin Dmitrievich", "Konstantin", "Levin", "Kostya", "Kitty", "Vronsky", 
                                 "Darya Alexandrova", "Dolly", "Karenin", "Alexei Alexandrovich"]
    
    for i in range(len(df)):
        
        current_entity = df['source'][i].lower()
        
        if (i > 0) and (current_entity in pronouns):
            
            j = i - 1
            previous_entity = df['source'][j]
            
            if previous_entity in allowed_replacement_names:
                df['source'][i] = previous_entity
        
            elif (previous_entity in pronouns):
                # continue going more and more sentences backward to find a non-pronoun
                while (j >= 0) and (previous_entity in pronouns):

                    j -= 1
                    previous_entity = df['source'][j]

                    if previous_entity in allowed_replacement_names:
                        df['source'][i] = previous_entity
        
        
    return df

# %%
kg_df = replace_pronouns(kg_df)
pd.Series(kg_df['source']).value_counts()[:50]
# Out:
# 42 Previous entity was he
# 41 Previous entity now is 2 Stepan Arkadyevitch
# 43 Previous entity was he
# 42 Previous entity now is he
# 42 Previous entity was he
# 41 Previous entity now is 2 Stepan Arkadyevitch
# 44 Previous entity was he
# 43 Previous entity now is he
# 43 Previous entity was he
# 42 Previous entity now is he
# 42 Previous entity was he
# 41 Previous entity now is 2 Stepan Arkadyevitch
# 151 Previous entity was she
# 150 Previous entity now is when  he
# 163 Previous entity was he
# 162 Previous entity now is little  who
# 168 Previous entity was he
# 167 Previous entity now is now  deceit
# 171 Previous entity was she
# 170 Previous entity now is open  she
# 179 Previous entity was she
# 178 Previous entity now is when  he
# 180 Previous entity was he
# 179 Previous entity now is she
# 179 Previous entity was she
# 178 Previous entity now is when  he
# 185 Previous entity was she
# 184 Previous entity now is muscles
# 225 Previous entity was she
# 224 Previous entity now is She
# 260 Previous entity was she
# 259 Previous entity now is He
# 466 Previous entity was he
# 465 Previous entity now is so  he
# 467 Previous entity was he
# 466 Previous entity now is he
# 466 Previous entity was he
# 465 Previous entity now is so  he
# 500 Previous entity was he
# 499 Previous entity now is second  he
# 536 Previous entity was she
# 535 Previous entity now is boy
# 537 Previous entity was she
# 536 Previous entity now is she
# 536 Previous entity was she
# 535 Previous entity now is boy
# 596 Previous entity was he
# 595 Previous entity now is I
# 597 Previous entity was she
# 596 Previous entity now is he
# 596 Previous entity was he
# 595 Previous entity now is I
# 605 Previous entity was he
# 604 Previous entity now is one
# 616 Previous entity was he
# 615 Previous entity now is They
# 626 Previous entity was he
# 625 Previous entity now is subdued  he
# 858 Previous entity was he
# 857 Previous entity now is appearance
# 924 Previous entity was she
# 923 Previous entity now is when  they
# 1020 Previous entity was he
# 1019 Previous entity now is surely  she
# 1067 Previous entity was he
# 1066 Previous entity now is force
# 1075 Previous entity was she
# 1074 Previous entity now is eyes
# 1076 Previous entity was he
# 1075 Previous entity now is she
# 1075 Previous entity was she
# 1074 Previous entity now is eyes
# 1090 Previous entity was he
# 1089 Previous entity now is there  he
# 1091 Previous entity was she
# 1090 Previous entity now is he
# 1090 Previous entity was he
# 1089 Previous entity now is there  he
# 1092 Previous entity was she
# 1091 Previous entity now is she
# 15658 Previous entity was she
# 15657 Previous entity now is when  carriage
# 15666 Previous entity was she
# 15665 Previous entity now is forever  I
# 15667 Previous entity was she
# 15666 Previous entity now is she
# 15666 Previous entity was she
# 15665 Previous entity now is forever  I
# 15668 Previous entity was he
# 15667 Previous entity now is she
# 15667 Previous entity was she
# 15666 Previous entity now is she
# 15666 Previous entity was she
# 15665 Previous entity now is forever  I
# 15676 Previous entity was she
# 15675 Previous entity now is She
# 15749 Previous entity was she
# 15748 Previous entity now is too  I
# 15823 Previous entity was she
# 15822 Previous entity now is
# 15828 Previous entity was she
# 15827 Previous entity now is luggage train
# 16073 Previous entity was he
# 16072 Previous entity now is one  that
# 16079 Previous entity was he
# 16078 Previous entity now is He
# 16080 Previous entity was he
# 16079 Previous entity now is he
# 16079 Previous entity was he
# 16078 Previous entity now is He
# 16149 Previous entity was she
# 16148 Previous entity now is certain  he
# 16150 Previous entity was he
# 16149 Previous entity now is she
# 16149 Previous entity was she
# 16148 Previous entity now is certain  he
# 16201 Previous entity was she
# 16200 Previous entity now is more  he
# 16204 Previous entity was he
# 16203 Previous entity now is why  he
# 16207 Previous entity was he
# 16206 Previous entity now is
# 16215 Previous entity was she
# 16214 Previous entity now is very Sergey blood
# 16249 Previous entity was he
# 16248 Previous entity now is who
# 16252 Previous entity was he
# 16251 Previous entity now is that
# 16280 Previous entity was he
# 16279 Previous entity now is
# 16281 Previous entity was he
# 16280 Previous entity now is he
# 16280 Previous entity was he
# 16279 Previous entity now is
# 16282 Previous entity was he
# 16281 Previous entity now is he
# 16281 Previous entity was he
# 16280 Previous entity now is he
# 16280 Previous entity was he
# 16279 Previous entity now is
# 16416 Previous entity was he
# 16415 Previous entity now is this
# 16489 Previous entity was he
# 16488 Previous entity now is now  relations
# 16520 Previous entity was he
# 16519 Previous entity now is We
# 16548 Previous entity was he
# 16547 Previous entity now is actual  which
# 16695 Previous entity was he
# 16694 Previous entity now is
# 16707 Previous entity was he
# 16706 Previous entity now is
# 16725 Previous entity was she
# 16724 Previous entity now is so  everyone
# 16731 Previous entity was he
# 16730 Previous entity now is whole  he
# 16777 Previous entity was he
# 16776 Previous entity now is one  which
# source
# he                       1330
#                           982
# she                       823
# I                         811
# it                        375
# He                        359
# Levin                     313
# you                       290
# She                       259
# who                       196
# Stiva                     181
# that                      178
# they                      164
# Vronsky                   156
# Anna                      148
# Kitty                     131
# It                        130
# You                        95
# Alexey Alexandrovitch      83
# They                       80
# we                         78
# what                       71
# when  he                   69
# which                      67
# Sergey Ivanovitch          59
# one                        56
# We                         48
# this                       44
# him                        43
# Dolly                      41
# so  he                     37
# when  she                  37
# how  he                    32
# now  he                    31
# That                       31
# her                        31
# how  it                    29
# so  she                    27
# eyes                       27
# Varenka                    26
# Why  you                   25
# now  she                   25
# face                       24
# how  I                     23
# This                       22
# everything                 22
# again  he                  22
# old  man                   21
# mother                     21
# Betsy                      20
# Name: count, dtype: int64

# %%
kg_df[:50]
# Out:
#                          source                   target       relation
# 0               unhappy  family                 own  way     is unhappy
# 1                    Everything         Oblonskys  house         was in
# 2                           she                same  him     discovered
# 3                 only  husband            painfully  it         lasted
# 4                 stray  people        common  Oblonskys           felt
# 5                  own  husband              three  days        been at
# 6         just kitchen coachman                  warning     walked off
# 7   days Stepan Arkadyevitch he           covered  study           woke
# 8                      once  he                     eyes       embraced
# 9                       now  he                    dream        thought
# 10                      how  it                                     was
# 11                                                              be sure
# 12                       Alabin                Darmstadt         giving
# 13              then  Darmstadt                  America         was in
# 14                      too  he          little Il table     remembered
# 15                    gaily  he                    smile       twinkled
# 16                           it                                was nice
# 17               light serge he         colored  morocco        dropped
# 18          where dressing gown          always  bedroom      stretched
# 19                           he                    brows     remembered
# 20                                                                   Ah
# 21                         that               everything       muttered
# 22                again  detail                      all    was present
# 23                          she                       me        forgive
# 24                            I                       it             is
# 25                    whole  he         whole  situation      reflected
# 26          painful  sensations                  quarrel           kept
# 27         unlucky drawing that                     hand            was
# 28         forever household he            still  horror        fussing
# 29                         this                                      ’s
# 30                          she                   letter           this
# 31                     much  he                    words            was
# 32                   when  they  unexpectedly  something    happened to
# 33                           he                    fault     succeed in
# 34                          who                     what      reflected
# 35                  idiotic  he                  himself          smile
# 36              Catching  sight              cruel  room      shuddered
# 37                          she                  husband        refused
# 38                        Stiva                       it        thought
# 39                         what                                      ’s
# 40                           he                   answer        said to
# 41        2 Stepan Arkadyevitch        truthful  himself            was
# 42                           he                  conduct  was incapable
# 43                           he   younger thirty himself             at
# 44                           he             better  wife            was
# 45                           he                     wife           felt
# 46                    knowledge                      her        managed
# 47                vaguely  wife                ago  fact        thought
# 48                    even  she          indulgent  view       supposed
# 49                           It                                  turned

# %%
# With more proper nouns, now consolidate into the same entity.  Will do the quick-and-dirty way
def normalize_entities(df):
    
    # Want to consolidate into Anna, Stiva, Levin,
    names_map = {
                    'Anna Arkadyevna': 'Anna',
                    'Stepan Arkadyevitch': 'Stiva',
                    'Oblonsky': 'Stiva',
                    'Konstantin Dmitrievich': 'Levin',
                    'Konstantin': 'Levin',
                    'Kostya': 'Levin',
                    'Darya Alexandrovna': 'Dolly'
                }
    
    for i in range(len(df)):
        
        current_entity = df['source'][i]
        if current_entity in names_map.keys():
            df['source'][i] = names_map[current_entity]
            
    return df

# %%
normalize_entities(kg_df)
pd.Series(kg_df['source']).value_counts()[:50]
# Out:
# source
# he                       1330
#                           982
# she                       823
# I                         811
# it                        375
# He                        359
# Levin                     313
# you                       290
# She                       259
# who                       196
# Stiva                     181
# that                      178
# they                      164
# Vronsky                   156
# Anna                      148
# Kitty                     131
# It                        130
# You                        95
# Alexey Alexandrovitch      83
# They                       80
# we                         78
# what                       71
# when  he                   69
# which                      67
# Sergey Ivanovitch          59
# one                        56
# We                         48
# this                       44
# him                        43
# Dolly                      41
# so  he                     37
# when  she                  37
# how  he                    32
# now  he                    31
# That                       31
# her                        31
# how  it                    29
# so  she                    27
# eyes                       27
# Varenka                    26
# Why  you                   25
# now  she                   25
# face                       24
# how  I                     23
# This                       22
# everything                 22
# again  he                  22
# old  man                   21
# mother                     21
# Betsy                      20
# Name: count, dtype: int64

# %%
pd.Series(kg_df['source']=='Oblonsky').value_counts()
# Out:
# source
# False    16807
# Name: count, dtype: int64
